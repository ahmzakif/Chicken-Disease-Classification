# %% [markdown]
# MobileNetV2 model
#
# ---

# %%
# Import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image

# Open file
import os
import PIL
from random import seed
# Model CNN (Deep learning network)
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense,\
GlobalAveragePooling2D, Dropout, Flatten
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %%
# Create function plot loss function and accuracy score graph
def plot_graph(model_values):
    ''' 
    Input : Model_values of keras.callbacks.History
    Return : Graph of Loss function and accuracy score between training dataset and vaildation dataset
    '''
    # Subplots
    fig, ax = plt.subplots(1, 2, figsize=(14,5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(model_values.history['loss'], label='Training Loss');
    plt.plot(model_values.history['val_loss'], label='Testing Loss');
    plt.legend(fontsize=12, loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss');
    
    # Plot MSE
    plt.subplot(1, 2, 2)
    
    plt.plot(model_values.history['accuracy'], label='Training Accuracy')
    plt.plot(model_values.history['val_accuracy'], label='Validation Accuracy')
    
    plt.legend(fontsize=12, loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

# %% [markdown]
# 00. Check GPU
#    ---

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8227984769728778514
# xla_global_id: -1
# ]

# %% [markdown]
# 01. Open Datasets
#    ---

# %%
# set state seed
seed(42)

# Open path file of dataset 
dataset_path_new = "dataset_train_valid_test"

train_dir = os.path.join(dataset_path_new, "train")
valid_dir = os.path.join(dataset_path_new, "valid")
test_dir = os.path.join(dataset_path_new, "test")

# %% [markdown]
# 02. Preprocessing Image Datasets
#    ---

# %%
# Set parameter of image 
# https://github.com/keras-team/keras/issues/8090#issuecomment-335155737
batch_size = 50 # Set the batch size for epoch cycle
img_height = 128 # Set the height of the picture
img_width = 128 # Set the width of the picture

# Rescale pixel to reduce image size before using in model
data_gen_train = ImageDataGenerator(rescale=1/255.)
data_gen_valid = ImageDataGenerator(rescale=1/255.)
data_gen_test = ImageDataGenerator(rescale=1/255.)

# %%
# Create training dataset 
train_dataset = data_gen_train.flow_from_directory(train_dir,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)
 

# Create validation dataset 
valid_dataset = data_gen_valid.flow_from_directory(valid_dir,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create testing dataset 
test_dataset = data_gen_test.flow_from_directory(test_dir,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)
# Out:
# Found 7758 images belonging to 4 classes.
# Found 834 images belonging to 4 classes.
# Found 813 images belonging to 4 classes.

# %% [markdown]
# ---

# %% [markdown]
# 03. MobileNetV2 Model Training
#    ---

# %% [markdown]
# Transfer Learning

# %%
# https://keras.io/api/applications/mobilenet/#mobilenetv2-function
# import MobileNetV2 model form keras API
# set input size of image of trianing is 128x128 (smallest size of MobileNetV2)
# due to we want to use transfer learning process 
# we must add `include_top=False` because we wan to add our input data 
# we decide default weigh for mode
mobv2_model = tf.keras.applications.MobileNetV2(input_shape=(128,128,3),
                                                include_top=False, # Transfer learning
                                                weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 3s 0us/step

# %%
# model summary
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
mobv2_model.summary()
# Out:
# Model: "mobilenetv2_1.00_128"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 2223872 (8.48 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
# fix weights and bias 
# train specifically custom head
mobv2_model.trainable=False

# %% [markdown]
# Add custom head and output layers

# %%
# Create output layer 
# We have 4 classes in our output we decide using activation="softmax" 
# for multi classification.
# Before output layer we decide use GlobalAveragePooling2D as 
# one type of flatten layer.
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(mobv2_model.output) # flatten
prediction_layer = tf.keras.layers.Dense(units=4, activation="softmax")(average_pooling_layer)

# %%
# Add Input layer and output layer 
model = tf.keras.models.Model(inputs=mobv2_model.input, 
                                    outputs=prediction_layer)

# %%
# Total params: 2,263,108
# Trainable params: 5,124 # add input layers and  output layers
# Non-trainable params: 2,257,984 --> fix layers
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                    5124      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 2263108 (8.63 MB)
# Trainable params: 5124 (20.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
# Compile the model         
model.compile(loss="categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
# Save checkpoints during training
checkpoint_path = "model/mobilenetV2/mobilenetv2_cp/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 mode="max",
                                                 verbose=1,
                                                 monitor="val_accuracy")

# %%
# Training model
# make sure you truely save checkpoint_path
history = model.fit(train_dataset,
          epochs=25,
          validation_data=valid_dataset,
          callbacks=[cp_callback])
# Out:
# Epoch 1/25
# 156/156 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7984
# Epoch 1: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 50s 308ms/step - loss: 0.5467 - accuracy: 0.7984 - val_loss: 0.3989 - val_accuracy: 0.8561
# Epoch 2/25
# 156/156 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8966
# Epoch 2: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 51s 329ms/step - loss: 0.3005 - accuracy: 0.8966 - val_loss: 0.3279 - val_accuracy: 0.8861
# Epoch 3/25
# 156/156 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9185
# Epoch 3: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 49s 317ms/step - loss: 0.2471 - accuracy: 0.9185 - val_loss: 0.2802 - val_accuracy: 0.9065
# Epoch 4/25
# 156/156 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9281
# Epoch 4: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 47s 300ms/step - loss: 0.2219 - accuracy: 0.9281 - val_loss: 0.2767 - val_accuracy: 0.9065
# Epoch 5/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9368
# Epoch 5: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 45s 289ms/step - loss: 0.1988 - accuracy: 0.9368 - val_loss: 0.2936 - val_accuracy: 0.8897
# Epoch 6/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9444
# Epoch 6: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 42s 271ms/step - loss: 0.1783 - accuracy: 0.9444 - val_loss: 0.2590 - val_accuracy: 0.9185
# Epoch 7/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9499
# Epoch 7: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 45s 289ms/step - loss: 0.1662 - accuracy: 0.9499 - val_loss: 0.2535 - val_accuracy: 0.9161
# Epoch 8/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9548
# Epoch 8: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 45s 289ms/step - loss: 0.1571 - accuracy: 0.9548 - val_loss: 0.2580 - val_accuracy: 0.9137
# Epoch 9/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9550
# Epoch 9: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 68s 436ms/step - loss: 0.1489 - accuracy: 0.9550 - val_loss: 0.2846 - val_accuracy: 0.9017
# Epoch 10/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9597
# Epoch 10: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 63s 403ms/step - loss: 0.1374 - accuracy: 0.9597 - val_loss: 0.2728 - val_accuracy: 0.9065
# Epoch 11/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9617
# Epoch 11: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 58s 372ms/step - loss: 0.1324 - accuracy: 0.9617 - val_loss: 0.2531 - val_accuracy: 0.9125
# Epoch 12/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9647
# Epoch 12: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 50s 317ms/step - loss: 0.1241 - accuracy: 0.9647 - val_loss: 0.2750 - val_accuracy: 0.9017
# Epoch 13/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9666
# Epoch 13: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 49s 312ms/step - loss: 0.1193 - accuracy: 0.9666 - val_loss: 0.2599 - val_accuracy: 0.9125
# Epoch 14/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9692
# Epoch 14: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 63s 402ms/step - loss: 0.1129 - accuracy: 0.9692 - val_loss: 0.2639 - val_accuracy: 0.9113
# Epoch 15/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9669
# Epoch 15: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 44s 281ms/step - loss: 0.1114 - accuracy: 0.9669 - val_loss: 0.2746 - val_accuracy: 0.9101
# Epoch 16/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9711
# Epoch 16: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 46s 293ms/step - loss: 0.1045 - accuracy: 0.9711 - val_loss: 0.2683 - val_accuracy: 0.9125
# Epoch 17/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9746
# Epoch 17: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 46s 293ms/step - loss: 0.0991 - accuracy: 0.9746 - val_loss: 0.2632 - val_accuracy: 0.9125
# Epoch 18/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9749
# Epoch 18: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 48s 311ms/step - loss: 0.0947 - accuracy: 0.9749 - val_loss: 0.2698 - val_accuracy: 0.9041
# Epoch 19/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9751
# Epoch 19: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 52s 330ms/step - loss: 0.0937 - accuracy: 0.9751 - val_loss: 0.2895 - val_accuracy: 0.9029
# Epoch 20/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9768
# Epoch 20: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 50s 317ms/step - loss: 0.0877 - accuracy: 0.9768 - val_loss: 0.2752 - val_accuracy: 0.9101
# Epoch 21/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9781
# Epoch 21: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 77s 490ms/step - loss: 0.0868 - accuracy: 0.9781 - val_loss: 0.2746 - val_accuracy: 0.9089
# Epoch 22/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9789
# Epoch 22: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 40s 259ms/step - loss: 0.0827 - accuracy: 0.9789 - val_loss: 0.2871 - val_accuracy: 0.9017
# Epoch 23/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9794
# Epoch 23: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 41s 264ms/step - loss: 0.0810 - accuracy: 0.9794 - val_loss: 0.2843 - val_accuracy: 0.9101
# Epoch 24/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9812
# Epoch 24: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 40s 254ms/step - loss: 0.0757 - accuracy: 0.9812 - val_loss: 0.2836 - val_accuracy: 0.9077
# Epoch 25/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9814
# Epoch 25: saving model to model/mobilenetV2/mobilenetv2_cp\cp.ckpt
# 156/156 [==============================] - 47s 302ms/step - loss: 0.0738 - accuracy: 0.9814 - val_loss: 0.2857 - val_accuracy: 0.9089

# %%
# plot graph 
plot_graph(history)

# %%
# convert the history.history dict to a pandas DataFrame:    
hist_df = pd.DataFrame(history.history) 
# save history to csv:  
hist_csv_file = 'model/mobilenetV2/history_mobilenetv2_tf.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
# save model
model.save("model/mobilenetV2/mobilenetv2.h5")
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---

# %% [markdown]
# Fine Tuning
#
# ---

# %%
img_height = 128 # Set the height of the picture
img_width = 128 # Set the width of the picture

# load model
mobv2_model = tf.keras.applications.MobileNetV2(input_shape=(img_height, img_width,3),
                                              include_top=False, # Transfer learning
                                              weights="imagenet",
                                              )  

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(mobv2_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in mobv2_model.layers[:fine_tune_at]:
    layer.trainable = False

# Make sure you have frozen the correct layers
for i, layer in enumerate(mobv2_model.layers):
    if i >= 95:
        print(i, layer.name, layer.trainable)

# Add input layers and output layers
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(mobv2_model.output) # flatten
prediction_layer = tf.keras.layers.Dense(units=4, activation="softmax")(average_pooling_layer)
fineture_model = tf.keras.models.Model(inputs=mobv2_model.input, 
                                     outputs=prediction_layer)

# Compile the model         
fineture_model.compile(loss="categorical_crossentropy", 
                       optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                       metrics=['accuracy'])
# Out:
# Number of layers in the base model:  154
# 95 block_10_depthwise_relu False
# 96 block_10_project False
# 97 block_10_project_BN False
# 98 block_11_expand False
# 99 block_11_expand_BN False
# 100 block_11_expand_relu True
# 101 block_11_depthwise True
# 102 block_11_depthwise_BN True
# 103 block_11_depthwise_relu True
# 104 block_11_project True
# 105 block_11_project_BN True
# 106 block_11_add True
# 107 block_12_expand True
# 108 block_12_expand_BN True
# 109 block_12_expand_relu True
# 110 block_12_depthwise True
# 111 block_12_depthwise_BN True
# 112 block_12_depthwise_relu True
# 113 block_12_project True
# 114 block_12_project_BN True
# 115 block_12_add True
# 116 block_13_expand True
# 117 block_13_expand_BN True
# 118 block_13_expand_relu True
# 119 block_13_pad True
# 120 block_13_depthwise True
# 121 block_13_depthwise_BN True
# 122 block_13_depthwise_relu True
# 123 block_13_project True
# 124 block_13_project_BN True
# 125 block_14_expand True
# 126 block_14_expand_BN True
# 127 block_14_expand_relu True
# 128 block_14_depthwise True
# 129 block_14_depthwise_BN True
# 130 block_14_depthwise_relu True
# 131 block_14_project True
# 132 block_14_project_BN True
# 133 block_14_add True
# 134 block_15_expand True
# 135 block_15_expand_BN True
# 136 block_15_expand_relu True
# 137 block_15_depthwise True
# 138 block_15_depthwise_BN True
# 139 block_15_depthwise_relu True
# 140 block_15_project True
# 141 block_15_project_BN True
# 142 block_15_add True
# 143 block_16_expand True
# 144 block_16_expand_BN True
# 145 block_16_expand_relu True
# 146 block_16_depthwise True
# 147 block_16_depthwise_BN True
# 148 block_16_depthwise_relu True
# 149 block_16_project True
# 150 block_16_project_BN True
# 151 Conv_1 True
# 152 Conv_1_bn True
# 153 out_relu True

# %%
# Save checkpoints during training
# follow value of vaildation scorce 
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/mobilenetV2/mobilenetv2_ft.h5', 
                             monitor= 'val_accuracy', 
                             mode= 'max', 
                             save_best_only = True, 
                             verbose= 1)

# %%
# Training model
# make sure you truely save checkpoint_path
history_ft = fineture_model.fit(train_dataset,  
                             epochs=25, 
                             validation_data=valid_dataset, 
                             callbacks=[checkpoint]) # fine tune continue form transfer learning
# Out:
# Epoch 1/25
# 156/156 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8853
# Epoch 1: val_accuracy improved from -inf to 0.50480, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 63s 381ms/step - loss: 0.3574 - accuracy: 0.8853 - val_loss: 11.4519 - val_accuracy: 0.5048
# Epoch 2/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9511
# Epoch 2: val_accuracy improved from 0.50480 to 0.52278, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 57s 364ms/step - loss: 0.1543 - accuracy: 0.9511 - val_loss: 9.1678 - val_accuracy: 0.5228
# Epoch 3/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9618
# Epoch 3: val_accuracy improved from 0.52278 to 0.55036, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 82s 526ms/step - loss: 0.1137 - accuracy: 0.9618 - val_loss: 7.8476 - val_accuracy: 0.5504
# Epoch 4/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9707
# Epoch 4: val_accuracy improved from 0.55036 to 0.65348, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 60s 382ms/step - loss: 0.0867 - accuracy: 0.9707 - val_loss: 4.5445 - val_accuracy: 0.6535
# Epoch 5/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9706
# Epoch 5: val_accuracy did not improve from 0.65348
# 156/156 [==============================] - 62s 396ms/step - loss: 0.0939 - accuracy: 0.9706 - val_loss: 4.7661 - val_accuracy: 0.6091
# Epoch 6/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9731
# Epoch 6: val_accuracy improved from 0.65348 to 0.76139, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 59s 381ms/step - loss: 0.0782 - accuracy: 0.9731 - val_loss: 2.1933 - val_accuracy: 0.7614
# Epoch 7/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9773
# Epoch 7: val_accuracy did not improve from 0.76139
# 156/156 [==============================] - 58s 371ms/step - loss: 0.0664 - accuracy: 0.9773 - val_loss: 4.6400 - val_accuracy: 0.7290
# Epoch 8/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9791
# Epoch 8: val_accuracy improved from 0.76139 to 0.88369, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 59s 380ms/step - loss: 0.0690 - accuracy: 0.9791 - val_loss: 1.0780 - val_accuracy: 0.8837
# Epoch 9/25
# 156/156 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9638
# Epoch 9: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 59s 376ms/step - loss: 0.1114 - accuracy: 0.9638 - val_loss: 10.0725 - val_accuracy: 0.5300
# Epoch 10/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9812
# Epoch 10: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 59s 381ms/step - loss: 0.0663 - accuracy: 0.9812 - val_loss: 1.9769 - val_accuracy: 0.7374
# Epoch 11/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9756
# Epoch 11: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 57s 367ms/step - loss: 0.0796 - accuracy: 0.9756 - val_loss: 2.9692 - val_accuracy: 0.5959
# Epoch 12/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9755
# Epoch 12: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 61s 393ms/step - loss: 0.0756 - accuracy: 0.9755 - val_loss: 2.6681 - val_accuracy: 0.7530
# Epoch 13/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9826
# Epoch 13: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 61s 392ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 4.4911 - val_accuracy: 0.5935
# Epoch 14/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9888
# Epoch 14: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 59s 378ms/step - loss: 0.0292 - accuracy: 0.9888 - val_loss: 1.0805 - val_accuracy: 0.8573
# Epoch 15/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9916
# Epoch 15: val_accuracy did not improve from 0.88369
# 156/156 [==============================] - 60s 384ms/step - loss: 0.0215 - accuracy: 0.9916 - val_loss: 0.9130 - val_accuracy: 0.8705
# Epoch 16/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9924
# Epoch 16: val_accuracy improved from 0.88369 to 0.90528, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 59s 376ms/step - loss: 0.0181 - accuracy: 0.9924 - val_loss: 0.7183 - val_accuracy: 0.9053
# Epoch 17/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9936
# Epoch 17: val_accuracy improved from 0.90528 to 0.90647, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 57s 363ms/step - loss: 0.0154 - accuracy: 0.9936 - val_loss: 0.7225 - val_accuracy: 0.9065
# Epoch 18/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9911
# Epoch 18: val_accuracy did not improve from 0.90647
# 156/156 [==============================] - 57s 366ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 1.2960 - val_accuracy: 0.8825
# Epoch 19/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9823
# Epoch 19: val_accuracy did not improve from 0.90647
# 156/156 [==============================] - 60s 388ms/step - loss: 0.0497 - accuracy: 0.9823 - val_loss: 1.0244 - val_accuracy: 0.9041
# Epoch 20/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9898
# Epoch 20: val_accuracy improved from 0.90647 to 0.91487, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 58s 372ms/step - loss: 0.0288 - accuracy: 0.9898 - val_loss: 1.0186 - val_accuracy: 0.9149
# Epoch 21/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9928
# Epoch 21: val_accuracy did not improve from 0.91487
# 156/156 [==============================] - 61s 394ms/step - loss: 0.0196 - accuracy: 0.9928 - val_loss: 1.4130 - val_accuracy: 0.9029
# Epoch 22/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9927
# Epoch 22: val_accuracy did not improve from 0.91487
# 156/156 [==============================] - 59s 380ms/step - loss: 0.0199 - accuracy: 0.9927 - val_loss: 1.6221 - val_accuracy: 0.8837
# Epoch 23/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9908
# Epoch 23: val_accuracy did not improve from 0.91487
# 156/156 [==============================] - 64s 409ms/step - loss: 0.0289 - accuracy: 0.9908 - val_loss: 1.0283 - val_accuracy: 0.8729
# Epoch 24/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9942
# Epoch 24: val_accuracy improved from 0.91487 to 0.92326, saving model to model/mobilenetV2\mobilenetv2_ft.h5
# 156/156 [==============================] - 71s 456ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.7005 - val_accuracy: 0.9233
# Epoch 25/25
# 156/156 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9939
# Epoch 25: val_accuracy did not improve from 0.92326
# 156/156 [==============================] - 66s 423ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.9223 - val_accuracy: 0.9053

# %%
# plot graph 
plot_graph(history_ft)

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history_ft.history) 
hist_df.head()

# save to csv: 
hist_csv_file = 'model/mobilenetV2/history_mobilenetv2_ft.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
# save model after fine tuning
fineture_model.save("model/mobilenetV2/mobilenetv2_ft.h5")

# %% [markdown]
# ---
